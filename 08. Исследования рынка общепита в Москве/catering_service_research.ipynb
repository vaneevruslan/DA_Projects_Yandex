# %% [markdown]
# <h1>Рынок заведений общественного питания Москвы<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта-и-данных" data-toc-modified-id="Описание-проекта-и-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта и данных</a></span><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Обзор-и-предобработка-данных" data-toc-modified-id="Обзор-и-предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обзор и предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследуем-кол-во-объектов-общественного-питания-по-категориям" data-toc-modified-id="Исследуем-кол-во-объектов-общественного-питания-по-категориям-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Исследуем кол-во объектов общественного питания по категориям</a></span></li><li><span><a href="#Исследуем-количество-посадочных-мест-объектов-общественного-питания-по-категориям" data-toc-modified-id="Исследуем-количество-посадочных-мест-объектов-общественного-питания-по-категориям-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Исследуем количество посадочных мест объектов общественного питания по категориям</a></span></li><li><span><a href="#Исследуем-соотношение-сетевых-и-несетевых-заведений" data-toc-modified-id="Исследуем-соотношение-сетевых-и-несетевых-заведений-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследуем соотношение сетевых и несетевых заведений</a></span></li><li><span><a href="#Определяем-топ-15-популярных-сетей-в-Москве" data-toc-modified-id="Определяем-топ-15-популярных-сетей-в-Москве-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Определяем топ-15 популярных сетей в Москве</a></span></li><li><span><a href="#Исследуем-количество-заведений-в-разрезе-административных-районов-Москвы" data-toc-modified-id="Исследуем-количество-заведений-в-разрезе-административных-районов-Москвы-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Исследуем количество заведений в разрезе административных районов Москвы</a></span></li><li><span><a href="#Исследуем-средние-рейтинги-по-категориям-заведений" data-toc-modified-id="Исследуем-средние-рейтинги-по-категориям-заведений-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Исследуем средние рейтинги по категориям заведений</a></span></li><li><span><a href="#Строим-фоновую-картограмму-средних-рейтингов-заведений-каждого-района-Москвы" data-toc-modified-id="Строим-фоновую-картограмму-средних-рейтингов-заведений-каждого-района-Москвы-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Строим фоновую картограмму средних рейтингов заведений каждого района Москвы</a></span></li><li><span><a href="#Определяем-топ-15-улиц-по-кол-ву-заведений-и-улицы-только-с-одним-заведением" data-toc-modified-id="Определяем-топ-15-улиц-по-кол-ву-заведений-и-улицы-только-с-одним-заведением-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Определяем топ-15 улиц по кол-ву заведений и улицы только с одним заведением</a></span></li><li><span><a href="#Строим-фоновую-картограмму-средних-чеков-в-заведениях-для-каждого-района" data-toc-modified-id="Строим-фоновую-картограмму-средних-чеков-в-заведениях-для-каждого-района-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Строим фоновую картограмму средних чеков в заведениях для каждого района</a></span></li><li><span><a href="#Вывод-по-разделу" data-toc-modified-id="Вывод-по-разделу-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Вывод по разделу</a></span></li></ul></li><li><span><a href="#Исследование-рынка-кофеен" data-toc-modified-id="Исследование-рынка-кофеен-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследование рынка кофеен</a></span><ul class="toc-item"><li><span><a href="#Изучаем-данные-по-количеству-кофеен" data-toc-modified-id="Изучаем-данные-по-количеству-кофеен-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучаем данные по количеству кофеен</a></span></li><li><span><a href="#Изучаем-время-работы-кофеен" data-toc-modified-id="Изучаем-время-работы-кофеен-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучаем время работы кофеен</a></span></li><li><span><a href="#Изучаем-рейтинги-кофеен" data-toc-modified-id="Изучаем-рейтинги-кофеен-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Изучаем рейтинги кофеен</a></span></li><li><span><a href="#Изучаем-стоимость-чашки-капучино-в-кофейнях" data-toc-modified-id="Изучаем-стоимость-чашки-капучино-в-кофейнях-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Изучаем стоимость чашки капучино в кофейнях</a></span></li><li><span><a href="#Изучаем-среднее-кол-во-посадочных-мест-по-округам" data-toc-modified-id="Изучаем-среднее-кол-во-посадочных-мест-по-округам-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Изучаем среднее кол-во посадочных мест по округам</a></span></li><li><span><a href="#Вывод-по-разделу-и-рекомендации" data-toc-modified-id="Вывод-по-разделу-и-рекомендации-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Вывод по разделу и рекомендации</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Описание проекта и данных

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Инвесторы из фонда `«Shut Up and Take My Money»` решили попробовать себя в новой области и открыть заведение общественного питания в Москве. Заказчики ещё не знают, что это будет за место: кафе, ресторан, пиццерия, паб или бар, — и какими будут расположение, меню и цены.
#
# Для этого они просят нас подготовить исследование рынка Москвы в целом, а также рынка кофеен (дать рекомендации для его успешного открытия) интересные особенности и презентовать полученные результаты, которые в будущем помогут в выборе подходящего инвесторам места.
#
# Для ответа на этот вопрос, нам нужно будет проделать следующие шаги:
#
# 1. Подготовить и преодработать данные;
# 2. Провести необходимый анализ, произведя расчеты и построив графики для ответа на поставленный вопрос от инвесторов;
# 3. Провести исследование рынка кофеен и дать рекомендации;
# 3. Сделать выводы и подготовить презентацию ([ссылка](https://disk.yandex.ru/i/Q1SjomSmV8RFCg)) с результатами исследования.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# В нашем распоряжении датасет с заведениями общественного питания Москвы, составленный на основе данных сервисов Яндекс Карты и Яндекс Бизнес на лето 2022 года.
#
# **Структура данных датасета:**
#
# - `name` — название заведения;
#
# - `address` — адрес заведения;
# - `category` — категория заведения, например «кафе», «пиццерия» или «кофейня»;
# - `hours` — информация о днях и часах работы;
# - `lat` — широта географической точки, в которой находится заведение;
# - `lng` — долгота географической точки, в которой находится заведение;
# - `rating` — рейтинг заведения по оценкам пользователей в Яндекс Картах (высшая оценка — 5.0);
# - `price` — категория цен в заведении, например «средние», «ниже среднего», «выше среднего» и так далее;
# - `avg_bill` — строка, которая хранит среднюю стоимость заказа в виде диапазона, например:
#
#
#     - «Средний счёт: 1000–1500 ₽»;
#     - «Цена чашки капучино: 130–220 ₽»;
#     - «Цена бокала пива: 400–600 ₽», и так далее;
#
#
# - `middle_avg_bill` — число с оценкой среднего чека, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Средний счёт»:
#
#
#     - Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
#     - Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
#     - Если значения нет или оно не начинается с подстроки «Средний счёт», то в столбец ничего не войдёт.
#
#
# - `middle_coffee_cup` — число с оценкой одной чашки капучино, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Цена одной чашки капучино»:
#
#
# - Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
# - Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
# - Если значения нет или оно не начинается с подстроки «Цена одной чашки капучино», то в столбец ничего не войдёт.
#
#
# - `chain` — число, выраженное 0 или 1, которое показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки):
#
#
#     - 0 — заведение не является сетевым
#     - 1 — заведение является сетевым
#
# - `district` — административный район, в котором находится заведение, например Центральный административный округ;
#
# - `seats` — количество посадочных мест.

# %% [markdown]
# # Обзор и предобработка данных

# %% [markdown]
# ## Обзор данных

# %%
# Имптортируем необходимые библиотеки

import pandas as pd
import numpy as np
from folium import Map, Marker, Choropleth
from folium.plugins import MarkerCluster
import json
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import express as px
from plotly import graph_objects as go
from plotly.subplots import make_subplots

# %%
# Для удобства отобразим все колонки таблицы и изменим их ширину

pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)

# %%
# Прочитаем и запишем в переменную данные из датафрейма
df = pd.read_csv('moscow_places.csv')

# %%
# Создадим функцию для обзора данных: выведем первые и последние 5 строк, общую информацию, количество и процент пропусков,
# кол-во и долю дубликатов и статистические данные по датафрейму. 
# Функция на вход будет принимать датафрейм.

def df_review(data):
    
    # Выведем первые и последние 5 строк из датафрейму
    print('{0:^125}'.format('Обзор данных датасета'))
    display(data)
    print('-'*120)
    
    # Выведем общую информацию по датафрейму
    print('{0:^125}'.format('Общая информация по датасету'),end='\n\n')
    data.info()
    print('-'*120)
    
    # Выведем кол-во и процент пропусков в колонках датафрейма
    print('{0:^125}'.format('Количество пропусков и их доля от всех строк в колонке'))
    # Посчитаем кол-во пропусков и их процент от общего числа строк в датафрейме по каждому столбцу
    num_of_nan = data.isnull().sum().to_frame().reset_index().merge \
    (round(data.isnull().mean()*100,2).to_frame().reset_index(), on='index', how='left')
    # Переимунуем названия колонок для удобства и выведем рез-т
    num_of_nan.columns = ['columns','nan_count','nan_ratio']
    num_of_nan['nan_ratio'] = num_of_nan['nan_ratio'].map('{0:.2f}%'.format)
    display(num_of_nan.sort_values(by='nan_count', ascending=False))
    print('-'*120)
    
    # Посчитаем кол-во и долю явных дубликатов в датафрейме
    print(f'Количество явных дубликатов в датасете: {data.duplicated().sum()}')
    print (f'Доля явных дубликатов в датасете: {round(100*data.duplicated().sum()/data.shape[0],2)}%')
    print('-'*120,end='\n\n')
    
    # Выведем информацию по статистическим данным датафрейма
    print('{0:^125}'.format('Обзор cтатистических данных по датасету'))
    display(data.describe())

# %%
# Проведем первичный обзор данных
df_review(df)
# Out:
#                                                     Обзор данных датасета
#                       name  category  \
# 0                   WoWфли      кафе
# 1           Четыре комнаты  ресторан
# 2                    Хазри      кафе
# 3     Dormouse Coffee Shop   кофейня
# 4                Иль Марко  пиццерия
# ...                    ...       ...
# 8401            Суши Мания      кафе
# 8402             Миславнес      кафе
# 8403               Самовар      кафе
# 8404          Чайхана Sabr      кафе
# 8405            Kebab Time      кафе
#
#                                          address  \
# 0                     Москва, улица Дыбенко, 7/1
# 1             Москва, улица Дыбенко, 36, корп. 1
# 2                 Москва, Клязьминская улица, 15
# 3            Москва, улица Маршала Федоренко, 12
# 4                Москва, Правобережная улица, 1Б
# ...                                          ...
# 8401               Москва, Профсоюзная улица, 56
# ...

# %% [markdown]
# **Вывод**
#
# После первичного обзора данных, можно сделать следующие выводы:
#
# - В нашем датафрейме находятся `8406` строк и `14` столбцов;
# - Есть значительное количество пропусков, в среднем около `50%` от всех строк в колонках `middle_coffee_cup`, `middle_avg_bill`, `price`, `avg_bill`, `seats` и `hours`, решим что с ними делать в дальнейшей предобработке;
# - Явные дубликаты в строках не были обнаружены, возможно есть неявные дубликаты, предпримем далее попытки найти их;
# - В целом, по статистическим данным каких-то особых выбросов мы не наблюдаем, поэтому ничего дополнительно проверять не будем;
# - Также, для удобства заменим значения в колонке `chain` в более понятный для нас вид при построении графиков (где 0 - `Несетевое заведение`, 1 - `Сетевое заведение`)

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Как мы заметили раннее, пропуски находятся в следующих столбцах:
#
# - `avg_bill` -  строка, которая хранит среднюю стоимость заказа в виде диапазона;
#
# - `middle_avg_bill` - число с оценкой среднего чека, которое указано только для значений из столбца `avg_bill`;
# - `middle_coffee_cup` - число с оценкой одной чашки капучино, которое указано только для значений из столбца `avg_bill`;
# - `price` - категория цен в заведении;
# - `seats` - количество посадочных мест;
# - `hours` - информация о днях и часах работы.
#
# Так как мы не можем удалить пропуски в этих колонках, потому что в таком случае будет потеряно больше половины данных, и также было бы некорректно с нашей стороны заполнять медианными или средними значением,к примеру в зависимости от категории заведения пропуски, будет целеесообразней на данном этапе оставить все как и есть и при необходимости, при дальнейшейм анализе ставить 'заглушки' для конкретных анализируемых колонок.

# %% [markdown]
# Займемся поиском неявных дубликатов в нашем датафрейме. Для этого попробуем сузить поиск исходя из названия заведения и его адреса, так как с небольшой вероятностью два заведения с одним названием будут находиться на одном адресе.

# %%
print('Количество неявных дубликатов по столбцам  name, address:', df.duplicated(subset=['name','address']).sum())
# Out:
# Количество неявных дубликатов по столбцам  name, address: 0

# %% [markdown]
# Как мы видим дубликаты не были найдены. Возможно заведения или адреса написаны в разных регистрах, попытаемся провести эксперимент еще раз, но уже с приведенными к нижнему регистру колонками `name` и `address`.

# %%
# Создадим для этого копию нашего дф
dfc = df.copy(deep=True)

# Приведем к нижнему регистру колонки
dfc['name'] = dfc['name'].str.lower()
dfc['address'] = dfc['address'].str.lower()

# Посмотрим, повлияло ли это как-нибудь на результат
print('Количество неявных дубликатов по столбцам  name, address:',  (dfc.duplicated(subset=['name','address'])).sum())
# Out:
# Количество неявных дубликатов по столбцам  name, address: 4

# %% [markdown]
# Наша теория была верна, таким образом мы получили `4 строки` с неявными дубликатами, взглянем на эти строки

# %%
dfc[dfc.duplicated(subset=['name','address'])]
# Out:
#                            name  category  \
# 215                        кафе      кафе
# 1511                  more poke  ресторан
# 2420  раковарня клешни и хвосты   бар,паб
# 3109            хлеб да выпечка      кафе
#
#                                       address  \
# 215              москва, парк ангарские пруды
# 1511  москва, волоколамское шоссе, 11, стр. 2
# 2420               москва, проспект мира, 118
# 3109              москва, ярцевская улица, 19
#
#                                      district  \
# 215           Северный административный округ
# 1511          Северный административный округ
# 2420  Северо-Восточный административный округ
# 3109          Западный административный округ
#
#                                                      hours        lat  \
# 215                                 ежедневно, 10:00–22:00  55.881438
# 1511  пн-чт 09:00–18:00; пт,сб 09:00–21:00; вс 09:00–18:00  55.806307
# ...

# %%
# Удалим из нашего датафрейма данные дубликаты по их индексам, записанным в отдельную переменную
rows_index = dfc[dfc.duplicated(subset=['name','address'])].index
df = df.drop(index=rows_index).reset_index(drop=True)

# %% [markdown]
# Для удобства переименуем значения в колонке с 'флагом', показывающим к какому типу относится заведение

# %%
# Производим замену
df['chain'] = df['chain'].replace({0:'Несетевое заведение',1:'Cетевое заведение'})

# %% [markdown]
# Создадим новый столбец, в котором будет только улица на которой находится заведение

# %%
# Для этого создадим функцию, которая будет принимать на вход строку с адресом и 'извлекать' из нее  только улицу
def street_extractor(row):
    
    # Разбиваем строку с полным адресом на подстроки, где разделителем будет выступать запятая
    address = row['address'].split(',')
    
    # Создаем список с ключевыми словами по которым будет извлекаться улица
    lst = (
            ['улица', 'ул.', 'проспект', 'пр-т', 'шоссе', 'ш.', 'район', 'микрорайон', 'переулок', 'проезд',  
             'площадь', 'бульвар', 'аллея', 'линия', 'заказник', 'музей-заповедник', 'набережная', 'памятник', 
             'квартал', 'кольцо', '-й километр', 'парк', 'тупик', 'просек', 'сквер', 'сад', 'мост', 'тоннель']
           )
    
    # Для каждого слова из списка ключевых слов ищем в списке с адресом соответствие
    for word in lst:
        for address_lst in address:
            # Если нашли, то возвращаем эту строку
            if word in address_lst: 
                return address_lst
    # Если же нет, то возвращаем 'unknown'
    return 'Неизвестно'

# %%
# Применим функцию и создадим столбец с улицами
df['street'] = df.apply(street_extractor, axis=1)

# %% [markdown]
# ```python
# data['address'].str.split(', ').str[1]
# ```

# %%
# Посмотрим остались ли адреса из которых не получилось 'извлечь' улицу
display(df[df['street'] == 'Неизвестно'][['address','street']])
# И также подсчитаем долю ненайденных в таком случае строк
print('Доля ненайденных улиц от общего числа строк составляет: {:.2%}'.format(len(df.query('street == "Неизвестно"'))/len(df)))
# Out:
#                     address      street
# 6305            Москва, № 7  Неизвестно
# 7762  Москва, Сумская, 2/12  Неизвестно
# Доля ненайденных улиц от общего числа строк составляет: 0.02%

# %% [markdown]
# Наша функция практически отработала отлично, за исключением двух строк, из-за их небольшого количества оставим все без изменений

# %% [markdown]
# Создадим еще один столбец с обозначением, что заведение работает ежедневно и круглосуточно (если это так, то значение будет - `True`, а иначе - `False`)

# %%
# Для начала посмотрим как много таких заведений
print('Количество заведений, работающих 24/7:', len(df[df['hours'].str.contains('ежедневно, круглосуточно') == True]))
# Out:
# Количество заведений, работающих 24/7: 730

# %%
# Создадим необходимый столбец
df['is_24/7'] = df['hours'].str.contains('ежедневно, круглосуточно')

# %% [markdown]
# **Вывод**
#
# Мы провели первичную предобработку данных, удалили неявные дубликаты, заменили значения в колонке `chain`, и добавили две колонки - с улицей, на котором расположено заведение и 'флагом', обозначающим его время работы.

# %% [markdown]
# # Анализ данных

# %% [markdown]
# ## Исследуем кол-во объектов общественного питания по категориям

# %%
# Подготовавливаем необходимые данные для графика

groupby_cat = (
    df.groupby('category', as_index=False)
    .agg(objects_num=('name', "count"))
    .sort_values(by='objects_num', ascending=False)
)

# %%
# Строим график
fig = go.Figure(data=[go.Pie(labels=groupby_cat['category'], 
                             values=groupby_cat['objects_num'], 
                             pull=[0.075])])

# Добавляем необходмые настройки и выводим его
fig.update_layout(title='Доля категорий по количеству объектов общественного питания')
fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-1.png" alt="newplot-1.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - Наибольшее количество заведений относится к категориям:
#
#     1. `кафе` - **28%** (2376 заведний);
#
#     2. `ресторан` - **24%** (2042 заведения);
#     3. `кофейня` - **17%** (1413 заведений).
#
#
# - Наименьшее количество заведений относится к категориям:
#
#     1. `булочная` - **3%** (256 заведний);
#
#     2. `столовая` - **4%** (315 заведения);
#     3. `быстрое питание` - **7%** (603 заведений).

# %% [markdown]
# ## Исследуем количество посадочных мест объектов общественного питания по категориям

# %%
# Подготовавливаем необходимые данные для графика

groupby_seats =(
    df.groupby('category', as_index=False)
    .agg(mean_seats=('seats', 'mean'),
        median_seats=('seats', 'median'))
    .sort_values(by='mean_seats')
)

# %%
# Строим график, добавляем необходимые настройки и выводим его

fig, ax = plt.subplots(ncols=2,figsize=(20,6))
fig.suptitle('Распределение среднего и медианного кол-ва посадочных мест по категориям', fontsize=16)


sns.barplot(x='category', y='mean_seats', data=groupby_seats, ax=ax[0])

for p in ax[0].patches:
    height = p.get_height()
    ax[0].text(p.get_x()+p.get_width()/2,
        height + 0.57,
        '{:.0f}'.format(height),
        fontsize=10,
        ha="center")

ax[0].set_title('Среднее количество')
ax[0].set_xlabel('Категория')
ax[0].set_ylabel('Кол-во посадочных мест')
ax[0].tick_params(axis='x', rotation=30)
    
sns.barplot(x='category', y='median_seats', data=groupby_seats, ax=ax[1])


for p in ax[1].patches:
    height = p.get_height()
    ax[1].text(p.get_x()+p.get_width()/2,
        height + 0.57,
        '{:.0f}'.format(height),
        fontsize=10,
        ha="center")

ax[1].set_title('Медианное количество')
ax[1].set_xlabel('Категория')
ax[1].set_ylabel('Кол-во посадочных мест')
ax[1].tick_params(axis='x', rotation=30)


plt.show()

# %% [markdown]
# **Вывод**
#
# - Как по средним, так и медианным значениям лидерами по количеству посадоных мест явлются `кофейня`, `ресторан` и `бар, паб` - в среднем больше `111` посадочных мест;
#
#
# - Меньше всего посадоных мест в заведениях типа `булочная`, `пиццерия` и `кафе`, в среднем от `89-97` мест.

# %% [markdown]
# ## Исследуем соотношение сетевых и несетевых заведений

# %% [markdown]
# Рассмотрим соотношение сетевых и несетевых заведений в датасете

# %%
# Подготовавливаем необходимые данные для графика

groupby_chain = (
    df.groupby('chain', as_index=False)
    .agg(object_num=('name', 'count'))
    .sort_values('object_num', ascending=False)
)

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig = go.Figure(data=[go.Pie(labels=groupby_chain['chain'], 
                             values=groupby_chain['object_num'], 
                             pull=[0.075])])

fig.update_layout(title='Доля сетевых и несетевых заведений')
fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-2.png" alt="newplot-2.png" border="0" />

# %% [markdown]
# **Вывод**
#
# **62%** (5199 заведений) относятся к `сетевому типу`, оставшиеся же **38%** (3203 заведения) к `несетевому`.

# %% [markdown]
# Изучим соотношение сетевых и несетевых заведений в разрезе их категорий. Для этого подготовим необходимые данные и построи графики.

# %%
# Подготовавливаем необходимые данные для графика

groupby_chain_cat = df.groupby(['category', 'chain'],as_index=False).agg(num_of_chain=('name','count'))
groupby_chain_cat = (groupby_chain_cat.merge
                     (df.groupby('category',as_index=False)
                      .agg(total_of_cat=('name','count')),
                     how='left'))
groupby_chain_cat['chain_ratio'] = (groupby_chain_cat['num_of_chain']/groupby_chain_cat['total_of_cat'])*100

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig, ax = plt.subplots(ncols=2,figsize=(20,6))
fig.suptitle('Соотношение сетевых и несетевых заведений в разрезе категорий (в абсолютном и относительном выражении)', fontsize=16)

sns.barplot(x='category', y='num_of_chain', hue='chain', data=groupby_chain_cat, ax=ax[0])

# Подписываем каждый столбик
for p in ax[0].patches:
    height = p.get_height()
    ax[0].text(p.get_x()+p.get_width()/2,
        height + 0.57,
        '{:.0f}'.format(height),
        fontsize=10,
        ha="center")

ax[0].set_title('Соотношение в абсолютном выражении')
ax[0].set_xlabel('Категория')
ax[0].set_ylabel('Кол-во заведений')
ax[0].tick_params(axis='x', rotation=30)
    
sns.barplot(x='category', y='chain_ratio',hue='chain', data=groupby_chain_cat, ax=ax[1])

# Подписываем каждый столбик
for p in ax[1].patches:
    height = p.get_height()
    ax[1].text(p.get_x()+p.get_width()/2,
        height + 0.15,
        '{:.0f}%'.format(height),
        fontsize=10,
        ha="center")

ax[1].set_title('Соотношение в относительном выражении')
ax[1].set_xlabel('Категория')
ax[1].set_ylabel('% Кол-во заведений')
ax[1].tick_params(axis='x', rotation=30)


plt.show()

# %% [markdown]
# **Вывод**
#
# - `Сетевые заведения` чаще всего преобладают в следующих категориях:
#
#     1. `булочная` - **61%** заведений;
#
#     2. `пиццерия` - **52%** заведений;
#     3. `кофейня` - **51%** заведений.
#
#
# - `Несетевые заведения` чаще всего преобладают в следующих категориях:
#
#     1. `бар, паб` - **78%** заведений;
#
#     2. `столовая` - **72%** заведений;
#     3. `кафе` - **67%** заведений.

# %% [markdown]
# ## Определяем топ-15 популярных сетей в Москве

# %%
# Подготовавливаем необходимые данные для графика

chain_objects = (df.query('chain == "Cетевое заведение"')
                 .groupby('name',as_index=False)
                 .agg(object_num=('name','count'))
                 .sort_values(by='object_num',ascending=False)
                 .head(15)
                )

# %%
# Строим график, добавляем необходмые настройки и выводим его

plt.figure(figsize=(20,10))

ax = sns.barplot(y='object_num', x='name', data=chain_objects, ec='black',color='lightblue')

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2,
        height + 0.57,
        '{:.0f}'.format(height),
        fontsize=12,
        ha="center")


plt.title('Топ-15 самых популярных сетевых заведений в Москве',fontsize=15)
plt.xlabel('Кол-во заведений',fontsize=13)
plt.ylabel('Название сети',fontsize=13)
plt.xticks(rotation=75)

plt.show()

# %% [markdown]
# **Вывод**
#
# - Первая тройка самый популярных сетевых заведений:
#
#     1. `Шоколадница` - **120** заведений;
#
#     2. `Домино'с Пицца` - **76** заведений;
#     3. `Додо Пицца` - **74** заведений.
#
#
# - Последняя тройка самый популярных сетевых заведений:
#
#     1. `Му-Му` - **27** заведения;
#
#     2. `CofeFest`  и `Буханка` - по **32** заведения.

# %% [markdown]
# Рассмотрим какая категория заведения преобладает среди топ-15 сетевых объектов

# %%
# Создаем список из названия топ-15 заведений
top15_lst = list(chain_objects['name'])

# Подготовавливаем необходимые данные для графика 
df_filtered = df.query('name in @top15_lst')
top15_category = df_filtered['category'].value_counts().to_frame().reset_index()
top15_category.columns = ['category','object_num']

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig = go.Figure(data=[go.Pie(labels=top15_category['category'], 
                             values=top15_category['object_num'], 
                             pull=[0.075])])

fig.update_layout(title='Доля категорий в сетевых заведениях из списка топ-15')
fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-3.png" alt="newplot-3.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - Более **41%** (336 заведений) из топ-15 относятся к `кофейне`, далее идет `ресторан` - **23%** (186 заведений) и замыкает тройку `пиццерия` - **19%** (151 заведение);
#
#
# - Чуть более **2%** (около 40 заведений) приходится на `булочную`, `бар, паб` и `столовую`

# %% [markdown]
# ## Исследуем количество заведений в разрезе административных районов Москвы

# %%
# Подготовавливаем необходимые данные для графика

groupby_district = (df.groupby('district', as_index=False)
                   .agg(object_num=('name','count'))
                   .sort_values(by='object_num', ascending=False))

district_category = (df.groupby(['district','category'], as_index=False)
                     .agg(object_num=('name','count'))
                     .sort_values(by='object_num')
                    )

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig=px.bar(district_category,
           x='object_num',
           y='district', 
           color = 'category', 
           orientation='h', 
           title="Количество заведений каждой категории в разрезе административного района",
          labels={'district':'Админ. район',
                 'object_num':'Кол-во заведений'},
          width=1000,
          height=600)

fig.add_trace(go.Scatter(
                y=groupby_district['district'], 
                x=groupby_district['object_num'],
                text=groupby_district['object_num'],
                mode='text',
                textposition='top right',
                textfont=dict(
                    size=9,
                ),
                showlegend=False
))
    
fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-4.png" alt="newplot-4.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - Больше всего заведений находится в:
#
#     1. `ЦАО` - **2242**;
#
#     2. `САО` - **898**;
#     3. `ЗАО` - **850**.
#
#
# - Меньше всего заведений находится в:
#
#     1. `СЗАО` - **409**;
#
#     2. `ЮВАО` - **714**;
#     3. `ВАО` - **798**.
#
#
# - В основом, во всех районах преобладают 3 категории: `кафе`, `ресторан` и `кофейня`, а меньше всего встречаются: `булочная`, `столовая` и `бар, паб`.

# %% [markdown]
# ## Исследуем средние рейтинги по категориям заведений

# %%
# Подготовавливаем необходимые данные для графика

cat_mean_rating = (df.groupby(['category'], as_index=False)
                  .agg(mean_rating=('rating','mean'))
                  .round(2)
                  .sort_values(by='mean_rating'))

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig = px.scatter(cat_mean_rating, 
                 x='category', 
                 y='mean_rating', 
                 size='mean_rating',
                 color="category",size_max=50,
                labels={'mean_rating': 'Средний рейтинг', 
                        'category': 'Тип заведения'},
                title='Средний рейтинг среди категории заведения', text='mean_rating',
                width=1100,
                height=500)

fig.update_layout(showlegend=False)

fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-5.png" alt="newplot-5.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - Средние рейтинги в разрезе категории объекта общественного питания находится примерно в одном, довольно хорошем уровне - от **4.05** у заведений `быстрого питания` до **4.39** баллов у `баров и пабов`.

# %% [markdown]
# ## Строим фоновую картограмму средних рейтингов заведений каждого района Москвы

# %% [markdown]
# Для начала построим фоновую картограмму со средним рейтингом заведений каждого района. Для этого используем необходимый файл с данными, предварительно все подготовив и затем выведем полученную карту.

# %%
# Читаем файл и сохраняем в переменной

with open('admin_level_geomap.geojson', 'r') as f:
    state_geo = json.load(f)

# %%
# Подготовавливаем необходимые данные для карты
district_rating = df.groupby('district',as_index=False)['rating'].mean().round(2)

# %%
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# Создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# Создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=district_rating,
    columns=['district', 'rating'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Средний рейтинг заведений по районам',
).add_to(m)

# Выводим карту
m

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/BEZYMYNNYI.png" alt="BEZYMYNNYI.png" border="0" />

# %% [markdown]
# **Вывод**
#
# В среднем, рейтинги по районам, как и в разрезе с категорией объекта общественного питания находятся на приличном большом уровне - от **4.1** в `ЮВАО` до **4.38** в `ЦАО`.

# %% [markdown]
# Теперь отобразим все заведения из датасета на карте с помощью кластеров.

# %%
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# Создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# Создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# Пишем функцию, которая принимает строку датафрейма,
# Создаёт маркер в текущей точке и добавляет его в кластер marker_cluster

def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# Применяем функцию create_clusters() к каждой строке датафрейма
df.apply(create_clusters, axis=1)

# Выводим карту
m

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/BEZYMYdNNYI.png" alt="BEZYMYdNNYI.png" border="0" />

# %% [markdown]
# Теперь в нашем распоряжении интерактивная карта с местоположением всех заведений и их рейтингами.

# %% [markdown]
# ## Определяем топ-15 улиц по кол-ву заведений и улицы только с одним заведением

# %% [markdown]
# Проилюстрируем на графике топ-15 улиц по количеству заведений и их категорией

# %%
# Создаем дф с топ-15 улицами по кол-ву заведений
top15_streets = (df.groupby('street', as_index=False)
                 .agg(object_num=('name','count'))
                 .sort_values(by='object_num', ascending=False)
                 .head(15)
                )

# Создаем список с этими улицами
top15_str_lst = list(top15_streets['street'])

# Готовим данные для графика
top15_streets_cat = (df.query('street in @top15_str_lst').groupby(['street','category'], as_index=False)
                     .agg(object_num=('name','count'))
                     .sort_values(by='object_num', ascending=False)
                    )

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig = px.bar(top15_streets_cat,
            y='street', 
            x='object_num', 
            color='category',
            orientation = 'h',
            labels={'street':'Улица', 'object_num':'Кол-во заведений'}, 
            title='Топ-15 улиц по количеству заведений в разрезе категорий объектов', 
            width=1000,
            height = 650)

fig.add_trace(go.Scatter(
                 y=top15_streets['street'], 
                 x=top15_streets['object_num'],
                 text=top15_streets['object_num'],
                 mode='text',
                 textposition='top right',
                 textfont=dict(
                     size=11,
                 ),
                 showlegend=False
))
fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-6.png" alt="newplot-6.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - Больше всего заведений находится на:
#
#     1. `Проспекте Мира` - **183**;
#
#     2. `Профсоюзная улица` - **122**;
#     3. `Проспект Вернадского` - **108**.
#
#
# - Меньше всего заведений находится на:
#
#     1. `Алтуфьевском шоссе` - **47**;
#
#     2. `Улице Пятницкая` - **48**;
#     3. `Улице Миклухо-Маклая` - **49**.
#
#
# - В основом, на всех улицах, как и в районах преобладают 3 категории: `кафе`, `ресторан` и `кофейня`, а меньше всего встречаются: `булочная`, `столовая` и `бар, паб`.

# %% [markdown]
# Теперь найдем улицы, на которых находится только один объект общепита. Для начала посчтитаем общее кол-во таких объектов.

# %%
# Подготовавливаем необходимые данные
one_object_streets = (df.groupby(['street'],as_index=False)
                      .agg(object_num=('name','count'))
                      .query('object_num == 1')
                     )
# Выводим результат
print('Общее кол-во улиц с одним заведением:', len(one_object_streets))
# Out:
# Общее кол-во улиц с одним заведением: 485

# %% [markdown]
# Подготовим данные и посмотрим к каким категориям заведений чаще всего относятся данные объекты

# %%
# Создадим список с улицами, где всего 1 объект общественного питания
one_object_streets_lst = list(one_object_streets['street'])

# Подготовавливаем необходимые данные для графика
one_object_streets_cat = (df.query('street in @one_object_streets_lst')
                            .groupby('category',as_index=False)
                            .agg(object_num=('name','count'))
                            .sort_values(by='object_num', ascending = False))

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig = go.Figure(data=[go.Pie(labels=one_object_streets_cat['category'], 
                             values=one_object_streets_cat['object_num'], 
                             pull=[0.075])])

fig.update_layout(title='Доля категории объекта в разрезе улиц с одним заведением')
fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-7.png" alt="newplot-7.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - В основом, на улицах с одним объектом преобладают:
#
#     1. `кафе` - **36%** заведений;
#
#     2. `ресторан` - **20%** заведений;
#     3. `кофейня` - **19%** заведений.

# %% [markdown]
# И дополнительно рассмотрим в каких районах больше всего улиц с одним заведением

# %%
# Подготовавливаем необходимые данные для графика

one_object_streets_distr = (df.query('street in @one_object_streets_lst')
                              .groupby('district',as_index=False)
                              .agg(object_num=('name','count'))
                              .sort_values(by='object_num', ascending = False))

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig = go.Figure(data=[go.Pie(labels=one_object_streets_distr['district'], 
                             values=one_object_streets_distr['object_num'], 
                             pull=[0.075])])

fig.update_layout(title='Доля улиц с одним заведением в разрезе административного района объекта')
fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-13.png" alt="newplot-13.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - Больше всего улиц с одним заведением находится в:
#
#     1. `ЦАО` - **30%**;
#
#     2. `ВАО` и `СВАО` - около **12%**.
#
#
# - Меньше всего улиц с одним заведением находится в:
#
#     1. `ЮЗАО` и `СЗАО` - около **4%**;
#
#     2. `ЮВАО` - **9%**.

# %% [markdown]
# ## Строим фоновую картограмму средних чеков в заведениях для каждого района

# %% [markdown]
# Для того, чтобы посторить картограмму средних чеков, нам нужно посчтитать медианнон значение средних чеков по каждому району и после этого отобразить полученный рез-т на карте

# %%
# Подготовавливаем необходимые данные для карты

distr_median_price = (df.groupby('district',as_index=False)
                      .agg(median_price=('middle_avg_bill','median'))
                      .round(2)
                      .sort_values(by='median_price',ascending=False)
                     )

# %%
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# Создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# Создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=distr_median_price,
    columns=['district', 'median_price'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Средний чек в заведениях по районам',
).add_to(m)

# Выводим карту
m

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/SNIMOK-EKRANA-2023-07-11-152329.jpg" alt="SNIMOK-EKRANA-2023-07-11-152329.jpg" border="0" />

# %% [markdown]
# **Вывод**
#
# - Самым высокий средний чек в заведениях находится в `ЦАО` и `ЗАО` - **1000 руб.**
#
# - Самый низкий средний чек в заведениях находится в `ЮВАО`, `ЮАО` и `СВАО` - **450-500 руб.**
# - Мы наблюдаем закономерность в снижении среднего чека в зависимости от удаленности от центра (за исключением `ЗАО`)

# %% [markdown]
# ## Вывод по разделу

# %% [markdown]
# - Наибольшее кол-во заведений по категориям у - `кафе`, `ресторана` и `кофейни`, наименьшее у - `булочной`, `столовой` и `быстрого питания`;
#
#
# - В среднем, лидерами по количеству посадоных мест явлются `кофейня`, `ресторан` и `бар, паб` - в среднем больше `111`
# посадочных мест, меньше всего посадоных мест в заведениях типа `булочная`, `пиццерия` и `кафе`;
#
#
# - Соотношение сетевых заведений к несетевым составляет **38%** на **62%**. Больше всего сетевых заведений у категорий -
# `булочная`, `пиццерия` и `кофейня`, а несетевых заведений у - `баров, пабов`, `столовых`и `кафе`;
#
#
# - Самые поплуряные сети из топ-15: `Шоколадница`, `Домино'с Пицца`, `Додо Пицца`. В разрезе категорий сетевых объектов общественного питания преобладают `кофейни`, `рестораны` и `пиццерии`;
#
#
# - Больше всего заведений находится в: `ЦАО`, `САО`, `ЗАО`, а меньше всего в `СЗАО`, `ЮВАО` и `ВАО`. Во всех районах преобладают 3 категории заведений: `кафе`, `ресторан` и `кофейня`, а меньше всего встречаются: `булочная`, `столовая` и `бар, паб`.
#
#
#
# - Средние рейтинги в разрезе категории объекта общественного питания находится на примерно одинаковом уровне - от **4.05** у заведений `быстрого питания` до **4.39** баллов у `баров и пабов`.
#
#
# - В среднем, рейтинги по районам, как и в разрезе с категорией объекта общественного питания находятся на практически одинаковом уровне - от **4.1** в `ЮВАО` до **4.38** в `ЦАО`.
#
#
#
# - Больше всего заведений находится на следующих улицах: `Проспекте Мира`, `Профсоюзной улице`и `Проспекте Вернадского`, а меньше всего находится на: `Алтуфьевском шоссе`, `Улице Пятницкая`, `Улице Миклухо-Маклая`. В основом, на всех улицах, как и в районах преобладают 3 категории: `кафе`, `ресторан` и `кофейня`, а меньше всего встречаются: `булочная`, `столовая` и `бар, паб`.
#
#
# - Общее кол-во улиц с одним заведением: **485**. Больше всего их в `ЦАО`, `ВАО` и `САО`. В основом, на улицах с одним объектом преобладают `кафе`, `рестораны` и `кофейни`;
#
#
# - Самый высокий средний чек в `ЦАО` И `ЗАО` - 1000 руб, низкий - `ЮВАО`, `ЮАО` и `СВАО`. Чем дальше заведение от центра, тем ниже средний чек (кроме `ЗАО`).

# %% [markdown]
#  # Исследование рынка кофеен

# %% [markdown]
# ## Изучаем данные по количеству кофеен

# %%
# Смотрим сколько кофеен в датасете

coffee_df = df.query('category == "кофейня"')
print('Всего кофеен в датасете:',len(coffee_df))
# Out:
# Всего кофеен в датасете: 1413

# %% [markdown]
# Теперь рассмотрим распределение кофеен по административным округам. Подготовим даннные и выведем график.

# %%
# Подготовавливаем необходимые данные для графика

coffee_distr = (coffee_df.groupby('district',as_index=False)
                .agg(object_num=('name','count'))
                .sort_values(by='object_num',ascending=False)
               )

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig = go.Figure(data=[go.Pie(labels=coffee_distr['district'], 
                             values=coffee_distr['object_num'], 
                             pull=[0.075])])

fig.update_layout(title='Распределение кофеен в разрезе административных округов')
fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-9.png" alt="newplot-9.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - Больше всего кофеен в:
#
#     1. `ЦАО` - **30%**;
#
#     2. `САО` - **14%**;
#     3. `СВАО` - **11%**.
#
#
# - Меньше всего кофеен в:
#
#     1. `СЗАО` - **4%**;
#
#     2. `ЮВАО` - **6%**;
#     3. `ЮЗАО` - **7%**.

# %% [markdown]
# ## Изучаем время работы кофеен

# %% [markdown]
# Рассмотрим соотношение кофеен по времени работы.

# %%
# Подготовавливаем необходимые данные для графика

coffee_working_hours = (coffee_df['is_24/7']
                        .value_counts()
                        .to_frame()
                        .reset_index()
                        .replace({'index':{False:'Не круглосуточный',True:'Круглосуточный'}})
                        .rename(columns={'index':'working_hours','is_24/7':'amount'})
                        )

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig = go.Figure(data=[go.Pie(labels=coffee_working_hours['working_hours'], 
                             values=coffee_working_hours['amount'], 
                             pull=[0.2],
                             rotation=90)])

fig.update_layout(title='Соотношение кофеен в разрезе времени работы')
fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-10.png" alt="newplot-10.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - Подавляющее большинство кофеен не круглосуточные - **96%**, круглосуточных всего **4%**.

# %% [markdown]
# Рассмотрим соотношение кофеен по времени работы в разрезе типа объекта

# %%
# Подготовавливаем необходимые данные для графика

around_the_clock_obj_ratio = (coffee_df.pivot_table
                              (index='chain',
                               columns='is_24/7',
                               values='name',
                               aggfunc=('count'))
                              .reset_index())

around_the_clock_obj_ratio.columns = ['chain','not_24/7','is_24/7']

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig = make_subplots(rows=1, 
                    cols=2, 
                    specs=[[{'type':'domain'}, {'type':'domain'}]],
                    subplot_titles=("Не круглосуточные кофейни", "Круглосуточные кофейни"))

fig.add_trace(go.Pie(labels=around_the_clock_obj_ratio['chain'], values=around_the_clock_obj_ratio['not_24/7'],pull=[0.05]),
              1, 1)
fig.add_trace(go.Pie(labels=around_the_clock_obj_ratio['chain'], values=around_the_clock_obj_ratio['is_24/7'], pull=[0.075]),
              1, 2)

fig.update_layout(title_text='Соотношение кофеен по типу объекта в разрезе времени работы')

fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-11.png" alt="newplot-11.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - Сетевые и несетевые кофейни практически поровну работает не круглосуточно
# - Подавляющее большинство круглосуточных кофеен - сетеевые (**85%**) и только **15%** из них несетевые.
#
# При открытии кофейни целесообразней выбрать не круглосуточный формат работы, так основная аудитория таких заведений посещает их в дневное/вечернее рабочее время.

# %% [markdown]
# ## Изучаем рейтинги кофеен

# %%
# Подготовавливаем необходимые данные для графика

coffee_distr_rating = (coffee_df.groupby(['district'], as_index=False)
                  .agg(mean_rating=('rating','mean'))
                  .round(2)
                  .sort_values(by='mean_rating'))

# %%
# Строим график, добавляем необходмые настройки и выводим его

fig = px.scatter(coffee_distr_rating, 
                 x='district', 
                 y='mean_rating', 
                 size='mean_rating',
                 color='district',size_max=50,
                labels={'mean_rating': 'Средний рейтинг', 
                        'district': 'Административный район'},
                title='Средний рейтинг кофеен по административным районам', text='mean_rating',
                width=1100,
                height=600)

fig.update_layout(showlegend=False)
fig.update_xaxes(tickangle=-45)

fig.show()

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/newplot-12.png" alt="newplot-12.png" border="0" />

# %% [markdown]
# **Вывод**
#
# - Средние рейтинги кофеен в разрезе адммнистративного района находится примерно на одном, достаточно высоком уровне - от **4.2** у `ЗАО` до **4.34** баллов у `ЦАО`.

# %% [markdown]
# ## Изучаем стоимость чашки капучино в кофейнях

# %% [markdown]
# Для начала изучим медианную стоимость чашки капучино по всей Москве (из того небольшого кол-ва данных по этому параметру, которые у нас имеются)

# %%
print("Медианная цена чашки капучино по Москве:", coffee_df['middle_coffee_cup'].median())
# Out:
# Медианная цена чашки капучино по Москве: 170.0

# %% [markdown]
# Теперь посмотрим на нее в разрезе административных округов

# %%
# Подготовавливаем необходимые данные для графика

coffee_median_cup_price = (coffee_df.groupby('district',as_index=False)
                      .agg(median_price=('middle_coffee_cup','median'))
                      .round(2)
                      .sort_values(by='median_price',ascending=False)
                   )

# %%
# moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# Создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)

# Создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=coffee_median_cup_price,
    columns=['district', 'median_price'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Медианная цена чашки капучино в разрезе округа',
).add_to(m)

# Выводим карту
m

# %% [markdown]
# <img src="https://ltdfoto.ru/images/2023/07/11/SNIMOK-EKRANA-2023-07-11-152650.jpg" alt="SNIMOK-EKRANA-2023-07-11-152650.jpg" border="0" />

# %% [markdown]
# **Вывод**
#
# - Самым высокий медианный чек в заведениях находится в `ЮЗАО` - **198 руб.** далее идут `ЦАО`и `ЗАО` - около **190 руб.**
#
# - Самый низкий медианный чек в заведениях находится в `ВАО` - **135 руб.** далее идут `ЮВАО` и `ЮАО` - около **150 руб.**

# %% [markdown]
# ## Изучаем среднее кол-во посадочных мест по округам

# %%
# Подготовавливаем необходимые данные для графика

coffee_seats = (coffee_df.groupby('district')
                .agg(mean_seats=('seats','mean'))
                .astype(int)
                .reset_index()
                .sort_values(by='mean_seats')
               )

# %%
# Строим график, добавляем необходмые настройки и выводим его

plt.figure(figsize=(20,10))
ax = sns.barplot(x='district', y='mean_seats', data=coffee_seats)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2,
        height + 0.57,
        '{:.0f}'.format(height),
        fontsize=15,
        ha="center")


plt.title('Распределение среднего кол-ва мест по округам',fontsize=15)
plt.xlabel('Округ',fontsize=13)
plt.ylabel('Среднее кол-во мест',fontsize=13)
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Вывод**
#
# - Меньше всего посадочных мест в `ЮВАО` - **70**, `ЮЗАО` и `СЗАО` практически одинаково - **86-87**
# - Больше всего посадочных мест `ЗАО` - **153** , `ЮАО` - **124** и `САО`- **117**

# %% [markdown]
# ## Вывод по разделу и рекомендации

# %% [markdown]
# **Вывод:**
#
# - Всего кофеен в предоставленном нам датасете - **1413**. Больше всего их в `ЦАО` - **30%** и `САО` - **14%**, а меньше в `СЗАО` - **4%** и `ЮЗАО` - **7%**;
#
#
# - **96%** кофеен работают не круглосуточно, в то же время **85%** круглосуточных кофеен - сетевые;
#
#
# - Средние рейтинги кофеен в разрезе адммнистративного окргуа примерно на одном уровне и составляют от **4.2** до **4.34** баллов;
#
#
# - Самая высокая медианная стоимость чашки капучино в заведениях находится в `ЮЗАО` - **198 руб.** далее идут `ЦАО`и `ЗАО` - около **190 руб.**, ниже всего в `ВАО` - **135 руб.**
#
#
# - Среди всех округов, наименьшее среднее кол-во посадочных мест в `ЮВАО` - **70**, наибольшее в `ЗАО` - **153**
#
#
#
#
#
# **Рекомендации:**
#
# После проведенного исследования можно сформулировать следующие рекомендации для открытия кофейни:
#
# 1. Место - `Юго-Западный административный округ`, так как там находится одно из наименьших количеств кофеен - **7%** (96 объектов), что дает нам возможность для большей конкурентоспособности по сравнению с другими округами, где кофеен гораздо больше;
#
#
# 2. Предпочтительно выбрать режим работы не круглосуточный (как вариант - ежеденво с 10:00 - 22:00), так как круглосуточный формат, в основном представлен в **85%** случаях только в сетевых кофейнях, мы же, на первоначальном этапе ограничиваемся только одним заведеним;
#
#
# 3. Рейтинг кофеен в данном округе на довольно высоком уровне - **4.28 балла**, практически ничем не уступает самому высокооцененному округу `ЦАО` - **4.34 балла**;
#
#
# 4. Также в пользу `ЮЗАО` можно выделить самую высокую медианную стоимость чашки капучино в **198 руб**, что дает нам потеницальную возможность заработать больше, снизив на первоначальном этапе цены на `10-15%` по сравнению с конкурентами в этом районе;
#
#
# 5. На первоначальном этапе по количеству посадочных мест будет достаточно ограничиться в **90**.

# %% [markdown]
# # Вывод

# %% [markdown]
# Мы провели исследование рынка заведений общественного питания Москвы. В ходе исследования мы решилими поставленные перед нами задачи:
#
# - Провели первчиную подготовку и предобработку данных, устранив все недочеты, и приведя данные датафрейма к пригодному для проведения анализа виду;
#
#
# - Выполнили непосредственный анализ рынка, ответив на все поставленные вопросы от инвесторов и дали необходимые рекомендации для открытия кофейни.
